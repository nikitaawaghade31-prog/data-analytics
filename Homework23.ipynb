# %%
s = "Nikita Awaghade"
print(s[0:6])
print(s[7:15])
print(s[:6])
print(s[7:])
print(s[:])
print(s[0:15:2])
print(s[1:15:2])
print(s[0:15:3])
print(s[2:15:2])
print(s[3:12])
print(s[-7:])
print(s[:-8])
print(s[-15:-9])
print(s[-8:-1])
print(s[::-1])
print(s[14:6:-1])
print(s[13:6:-1])
print(s[5:0:-1])
print(s[10:2:-2])
print(s[14:0:-2])
# Out:
# Nikita
# Awaghade
# Nikita
# Awaghade
# Nikita Awaghade
# Nkt wgae
# iiaAahd
# Ni aa
# kt wgae
# ita Awagh
# waghade
# Nikita
# Nikita
# Awaghad
# edahgawA atikiN
# edahgawA
# dahgawA
# atiki
# gw t
# eagw tk
